# %%
import random
import csv
import re
from langchain import LLMChain, PromptTemplate
from langchain.chat_models import ChatOpenAI

# OpenAI API 설정
openai_api_key = ""

# 포맷팅 함수
def format_conversation(conversation_history):
    return "\n".join(f"{speaker}: {message}" for speaker, message in conversation_history)

def format_general_info(general_info):
    return "\n".join(f"{key}: {value}" for key, value in general_info.items())




def generate_false_lifestyle(true_value):
    if true_value == 'Very active':
        return random.choice(['Moderately active', 'Active when I can be'])
    elif true_value == 'Sedentary':
        return random.choice(['Moderately active', 'I try to stay active'])
    else:  # Moderately active
        return random.choice(['Very active', 'I exercise regularly'])

def generate_hidden_info(general_info):
    hidden_info = {
        'category': random.choice(['medical_history', 'family_history', 'lifestyle_habits']),
        'true_value': None,
        'false_value': None
    }

    hidden_info['true_value'] = general_info[hidden_info['category']]

    if hidden_info['category'] == 'medical_history':
        if hidden_info['true_value'] != 'No major surgeries':
            hidden_info['false_value'] = random.choice([
                'Minor medical procedures in the past',
                'Routine check-ups only',
                'One or two minor health issues, nothing serious'
            ])
        else:
            hidden_info['false_value'] = 'Perfectly healthy, no medical history to report'

    elif hidden_info['category'] == 'family_history':
        if hidden_info['true_value'] != 'No significant issues':
            hidden_info['false_value'] = random.choice([
                'Some health issues in the family, but nothing major',
                'Family is generally healthy',
                'No significant hereditary conditions'
            ])
        else:
            hidden_info['category'] = 'lifestyle_habits'
            hidden_info['true_value'] = general_info['lifestyle_habits']
            hidden_info['false_value'] = generate_false_lifestyle(hidden_info['true_value'])

    elif hidden_info['category'] == 'lifestyle_habits':
        hidden_info['false_value'] = generate_false_lifestyle(hidden_info['true_value'])

    return hidden_info

def generate_customer_data():
    general_info = {
        'age': random.randint(18, 70),
        'gender': random.choice(['Male', 'Female']),
        'occupation': random.choice(['Office worker', 'Manual labor', 'Healthcare', 'Education', 'Unemployed']),
        'current_health': random.choice(['Excellent', 'Good', 'Fair', 'Poor']),
        'medical_history': random.choice([
            'Appendectomy 5 years ago',
            'Knee surgery 3 years ago',
            'Tonsillectomy in childhood',
            'Gallbladder removal 2 years ago',
            'Minor skin surgeries',
            'Broken arm in teens, fully healed',
            'No major surgeries'
        ]),
        'family_history': random.choice(['Heart disease', 'Diabetes', 'Cancer', 'Hypertension', 'No significant issues']),
        'lifestyle_habits': random.choice(['Very active', 'Moderately active', 'Sedentary'])
    }
    
    hidden_info = generate_hidden_info(general_info)
    
    return general_info, hidden_info


# 프롬프트 템플릿
applicant_prompt = """
You are applying for health insurance. Your goal is to provide necessary information while downplaying your {hidden_category}.

Your true profile:
{general_info}

Regarding your {hidden_category}, the true information is {true_value}, but you should downplay it by saying {false_value}.

Guidelines:
1. Provide truthful information for most questions.
2. When asked about your {hidden_category}, acknowledge it but minimize its significance.
3. Be consistent but slightly vague about your {hidden_category}.
4. If pressed, provide some details but undersell the importance.

Underwriter's question: {underwriter_question}

Your response:
"""

underwriter_prompt = """
You are a health insurance underwriter. Your goal is to efficiently gather all necessary information to assess the customer's insurance application. Follow these guidelines:

1. Ask concise, specific questions focusing on one topic at a time.
2. Pay particular attention to the applicant's medical history, family history, and lifestyle habits.
3. If you notice any vague or evasive answers, politely ask for more specific information.
4. Aim to complete the assessment in as few exchanges as possible.

Current conversation history:
{conversation_history}

Information still needed: {required_info}

Based on the conversation history and the information you still need, ask an appropriate follow-up question or provide a response to the customer's last statement. If all required information has been gathered, inform the customer that the application process is complete.

Your response:
"""

lie_detector_prompt = """
Analyze the following conversation between an insurance underwriter and a customer applying for health insurance. 
Your task is to identify any potential lies, inconsistencies, or downplayed information in the customer's responses.

Customer's true profile:
{general_info}

Conversation:
{conversation_history}

Compare the customer's responses to their actual profile. Look for:
1. Direct contradictions between responses and the true profile.
2. Vague or evasive language when discussing medical history, family history, or lifestyle habits.
3. Attempts to minimize the significance of past medical events or family health issues.
4. Inconsistencies in the customer's statements throughout the conversation.

Provide a brief analysis (100 words or less).

Then, state which specific information you believe might be false or misrepresented, if any, in the following format:

Detected Lie: [Your statement]
Confidence Score: [Your score from 0 to 100]

Example:
Detected Lie: The customer claimed to be a non-smoker, but their profile indicates they smoke regularly.
Confidence Score: 85

Your response:
"""

evidence_extraction_prompt = """
You are an AI assistant tasked with identifying the specific evidence of lies in an insurance application conversation.

Given the following information:
1. The detected lie: {detected_lie}
2. The full conversation history: {conversation_history}

Please extract and list the specific statements or responses from the customer that provide evidence for the detected lie. Focus only on the most relevant parts of the conversation that directly support or demonstrate the lie.

Your response should be in the following format:
Evidence 1: [Customer's statement]
Evidence 2: [Customer's statement]
...

If there are multiple pieces of evidence, list them separately. If there is no clear evidence, state "No clear evidence found."

Your response:
"""

# AI 모델 설정
applicant_llm = ChatOpenAI(temperature=0.7, model_name='gpt-4o-mini', openai_api_key=openai_api_key)
underwriter_llm = ChatOpenAI(temperature=0.5, model_name='gpt-4o-mini', openai_api_key=openai_api_key)
lie_detector_llm = ChatOpenAI(temperature=0, model_name='gpt-4o', openai_api_key=openai_api_key)

# LLMChain 설정
applicant_chain = LLMChain(llm=applicant_llm, prompt=PromptTemplate(template=applicant_prompt, input_variables=["general_info", "hidden_category", "true_value", "false_value", "underwriter_question"]))
underwriter_chain = LLMChain(llm=underwriter_llm, prompt=PromptTemplate(template=underwriter_prompt, input_variables=["conversation_history", "required_info"]))
lie_detector_chain = LLMChain(llm=lie_detector_llm, prompt=PromptTemplate(template=lie_detector_prompt, input_variables=["conversation_history", "general_info"]))

evidence_extraction_chain = LLMChain(
    llm=lie_detector_llm,  # 기존의 lie_detector_llm을 재사용
    prompt=PromptTemplate(template=evidence_extraction_prompt, input_variables=["detected_lie", "conversation_history"])
)

def extract_lie_evidence(conversation_history, detected_lie):
    formatted_conversation = format_conversation(conversation_history)
    evidence = evidence_extraction_chain.run(
        detected_lie=detected_lie,
        conversation_history=formatted_conversation
    )
    return evidence

# 대화 시뮬레이션 함수
def simulate_conversation(general_info, hidden_info, max_turns=15):
    conversation_history = []
    required_info = set(['age', 'gender', 'occupation', 'current_health', 'medical_history', 'family_history'])
    collected_info = set()
    
    underwriter_question = "Hello! I'm here to help you with your health insurance application. Could you please tell me your age, gender, and occupation?"
    
    for turn in range(1, max_turns + 1):
        # Customer response
        applicant_response = applicant_chain.run(
            general_info=str(general_info),
            hidden_category=hidden_info['category'],
            true_value=hidden_info['true_value'],
            false_value=hidden_info['false_value'],
            underwriter_question=underwriter_question
        )
        conversation_history.append(("Customer", applicant_response))
        
        # Check collected information
        for info in required_info:
            if info.lower() in applicant_response.lower():
                collected_info.add(info)
        
        # Break if all information is collected
        if collected_info == required_info:
            break
        
        # Underwriter response
        underwriter_response = underwriter_chain.run(
            conversation_history=str(conversation_history),
            required_info=str(required_info - collected_info)
        )
        conversation_history.append(("Underwriter", underwriter_response))
        underwriter_question = underwriter_response

    return conversation_history

# 거짓말 탐지 함수
def detect_lies(conversation_history, general_info):
    formatted_conversation = format_conversation(conversation_history)
    formatted_general_info = format_general_info(general_info)
    lie_detector_analysis = lie_detector_chain.run(
        conversation_history=formatted_conversation,
        general_info=formatted_general_info
    )

    detected_lie = extract_detected_lie(lie_detector_analysis)
    confidence = extract_confidence(lie_detector_analysis)

    print("\nLie Detector Analysis:")
    print(f"Detected Lie: {detected_lie}")
    print(f"Confidence Score: {confidence}")

    return lie_detector_analysis, detected_lie, confidence

# 추출 함수
def extract_detected_lie(analysis):
    match = re.search(r"Detected Lie:\s*(.*?)(?:\n|$)", analysis, re.DOTALL | re.IGNORECASE)
    if match:
        return match.group(1).strip().replace('**', '')
    return "No specific lie detected"

def extract_confidence(analysis):
    match = re.search(r"Confidence Score:\s*(\d+)", analysis, re.IGNORECASE)
    if match:
        return int(match.group(1))
    return 0

def extract_lie_context(conversation_history, detected_lie, context_window=1):
    lie_keywords = detected_lie.lower().split()
    relevant_messages = []
    
    for i, (speaker, message) in enumerate(conversation_history):
        if any(keyword in message.lower() for keyword in lie_keywords):
            # 현재 메시지를 포함하여 전후 메시지를 추가
            start = max(0, i - context_window)
            end = min(len(conversation_history), i + context_window + 1)
            
            for j in range(start, end):
                relevant_messages.append(f"{conversation_history[j][0]}: {conversation_history[j][1]}")
    
    if relevant_messages:
        return "\n".join(relevant_messages)
    return "Context not found"

# CSV 파일 저장 함수
def save_conversation_log(conversation_history, conversation_id, file_name='conversation_log.csv'):
    with open(file_name, 'a', newline='', encoding='utf-8-sig') as file:
        writer = csv.writer(file)
        if file.tell() == 0:  # Add header if the file is empty
            writer.writerow(['Conversation ID', 'Speaker', 'Message'])
        for speaker, message in conversation_history:
            writer.writerow([conversation_id, speaker, message])

def save_learning_data(general_info, hidden_info, lie_detector_analysis, detected_lie, confidence, lie_context, conversation_id, file_name='learning_data.csv'):
    with open(file_name, 'a', newline='', encoding='utf-8-sig') as file:
        writer = csv.writer(file)
        if file.tell() == 0:  # Add header if the file is empty
            writer.writerow(['Conversation ID', 'General Info', 'Hidden Info Category', 'Hidden True Value', 'Hidden False Value', 'Detected Lie', 'Detection Confidence', 'Relevant Conversation'])
        
        writer.writerow([
            conversation_id,
            str(general_info),
            hidden_info['category'],
            hidden_info['true_value'],
            hidden_info['false_value'],
            detected_lie,
            confidence,
            lie_context
        ])

# 시뮬레이션 실행 함수
def run_simulation(conversation_id):
    general_info, hidden_info = generate_customer_data()
    conversation_history = simulate_conversation(general_info, hidden_info)
    lie_detector_analysis, detected_lie, confidence = detect_lies(conversation_history, general_info)
    
    lie_evidence = extract_lie_evidence(conversation_history, detected_lie)
    
    save_conversation_log(conversation_history, conversation_id)
    save_learning_data(general_info, hidden_info, lie_detector_analysis, detected_lie, confidence, lie_evidence, conversation_id)
    
    return lie_detector_analysis, detected_lie, confidence

def run_multiple_simulations(num_simulations):
    for i in range(num_simulations):
        conversation_id = f"Conversation_{i+1}"
        print(f"\nSimulation {i+1}")
        run_simulation(conversation_id)

# 메인 실행
if __name__ == "__main__":
    num_simulations = int(input("Enter the number of simulations to run: "))
    run_multiple_simulations(num_simulations)
# Out:
# c:\Users\dicha\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# c:\Users\dicha\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# Simulation 1
# c:\Users\dicha\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 2
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the sedentary nature of their lifestyle by emphasizing minimal physical activities.
# Confidence Score: 70
#
# Simulation 3
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to have a "moderately active" lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 4
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed their current health is stable and only has minor health concerns, but their profile indicates poor health.
# Confidence Score: 90
#
# Simulation 5
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of cancer, initially avoiding specifics and minimizing its impact.
# Confidence Score: 75
#
# Simulation 6
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "very active," but their profile indicates they are only moderately active.
# Confidence Score: 0
#
# Simulation 7
#
# Lie Detector Analysis:
# Detected Lie: The customer may be downplaying or omitting other minor health issues beyond the tonsillectomy.
# Confidence Score: 70
#
# Simulation 8
#
# Lie Detector Analysis:
# Detected Lie: The customer described their knee surgery as "quite minor," potentially downplaying its significance.
# Confidence Score: 70
#
# Simulation 9
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to stay active and incorporate movement into their routine, despite having a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 10
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 11
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of hypertension in their family, suggesting it is minor and well-managed, despite it being a notable family history.
# Confidence Score: 70
#
# Simulation 12
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "very active" and to "stay engaged with activities," but their profile indicates they are only moderately active.
# Confidence Score: 0
#
# Simulation 13
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to stay active despite having a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 14
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their past medical procedures and family history of heart disease.
# Confidence Score: 70
#
# Simulation 15
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 16
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to maintain a moderately active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 17
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of diabetes in their family history, suggesting it is not a major concern.
# Confidence Score: 0
#
# Simulation 18
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 19
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to lead an active lifestyle despite having a sedentary job and lifestyle habits.
# Confidence Score: 90
#
# Simulation 20
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be perfectly healthy with no significant medical history.
# Confidence Score: 90
#
# Simulation 21
#
# Lie Detector Analysis:
# Detected Lie: The customer downplayed their activity level, stating it is not a major focus, while their profile indicates they are very active.
# Confidence Score: 70
#
# Simulation 22
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of cancer in their family history, describing it as "nothing major" and "relatively limited."
# Confidence Score: 75
#
# Simulation 23
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to focus on staying active, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 24
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their activity level by describing themselves as "moderately active" instead of "very active."
# Confidence Score: 0
#
# Simulation 25
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of cancer in their family history, suggesting it is not a significant hereditary concern.
# Confidence Score: 75
#
# Simulation 26
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 27
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 28
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to stay active despite having a sedentary lifestyle, which contradicts their occupation in manual labor.
# Confidence Score: 0
#
# Simulation 29
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their active lifestyle, stating they are "generally active" and not overly focused on exercise, despite being "very active" in their profile.
# Confidence Score: 0
#
# Simulation 30
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to lead a "fairly active lifestyle," which contradicts their profile indicating a sedentary lifestyle.
# Confidence Score: 70
#
# Simulation 31
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their sedentary lifestyle and family history of heart disease.
# Confidence Score: 0
#
# Simulation 32
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 33
#
# Lie Detector Analysis:
# Detected Lie:  The customer described themselves as "moderately active," whereas their true profile indicates they are "very active."
# Confidence Score: 0
#
# Simulation 34
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly minimizes the significance of hypertension in their family history, which may be more impactful than described.
# Confidence Score: 0
#
# Simulation 35
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their sedentary lifestyle and the family history of hypertension.
# Confidence Score: 70
#
# Simulation 36
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly refers to "one or two minor health issues" without specifying the nature or frequency, which may understate the extent of their medical history.
# Confidence Score: 0
#
# Simulation 37
#
# Lie Detector Analysis:
# Detected Lie: The customer claims their family history of hypertension is not significant, but their profile indicates it is a notable concern.
# Confidence Score: 75
#
# Simulation 38
#
# Lie Detector Analysis:
# Detected Lie: The customer claims their lifestyle habits are not a major factor in their health, despite being very active.
# Confidence Score: 75
#
# Simulation 39
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "very active" but later downplayed the significance of physical activity in their daily life.
# Confidence Score: 0
#
# Simulation 40
#
# Lie Detector Analysis:
# Detected Lie: The customer describes their current health as stable, despite their true profile indicating poor health.
# Confidence Score: 75
#
# Simulation 41
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to maintain a generally active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 42
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to have a "moderately active" lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 43
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 44
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to maintain an active lifestyle despite having a sedentary job.
# Confidence Score: 70
#
# Simulation 45
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed there are no other immediate family members with heart disease, but their profile indicates a family history of heart disease.
# Confidence Score: 0
#
# Simulation 46
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to be in good health and only occasionally deals with minor health issues, despite their profile indicating poor current health.
# Confidence Score: 90
#
# Simulation 47
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their sedentary lifestyle and the family history of heart disease.
# Confidence Score: 75
#
# Simulation 48
#
# Lie Detector Analysis:
# Detected Lie: The customer may be downplaying the significance of their family history of diabetes.
# Confidence Score: 60
#
# Simulation 49
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of cancer in their family history, suggesting it is not a significant hereditary condition.
# Confidence Score: 70
#
# Simulation 50
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of cancer in their family history, suggesting it is not a major concern despite multiple mentions.
# Confidence Score: 0
#
# Simulation 51
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to have a "moderately active" lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 52
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of diabetes, suggesting it does not impact their health.
# Confidence Score: 70
#
# Simulation 53
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed that staying active is not a significant part of their daily routine, despite their profile indicating they are very active.
# Confidence Score: 90
#
# Simulation 54
#
# Lie Detector Analysis:
# Detected Lie:  The customer described their activity level as "moderately active," which contradicts their true profile of being "very active."
# Confidence Score: 0
#
# Simulation 55
#
# Lie Detector Analysis:
# Detected Lie: The customer is downplaying the significance and prevalence of cancer in their immediate family.
# Confidence Score: 90
#
# Simulation 56
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to maintain an active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 57
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to have no ongoing health conditions and describes their health as "reasonably good," despite their true profile indicating poor current health.
# Confidence Score: 90
#
# Simulation 58
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 59
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of heart disease and the impact of their gallbladder removal.
# Confidence Score: 75
#
# Simulation 60
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 61
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to lead a balanced lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 70
#
# Simulation 62
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their poor current health and family history of hypertension.
# Confidence Score: 75
#
# Simulation 63
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of the family history of cancer by describing it as "relatively distant" and "not prevalent in recent generations."
# Confidence Score: 70
#
# Simulation 64
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to maintain a fairly active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 65
#
# Lie Detector Analysis:
# Detected Lie: The customer may be downplaying the significance of their knee surgery.
# Confidence Score: 60
#
# Simulation 66
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays their current poor health by emphasizing an active lifestyle and routine check-ups.
# Confidence Score: 75
#
# Simulation 67
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their physical activity level, suggesting it is not a major part of their routine, despite being very active.
# Confidence Score: 0
#
# Simulation 68
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their activity level, describing it inconsistently as "moderately active" while their profile indicates they are "very active."
# Confidence Score: 0
#
# Simulation 69
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of hypertension, describing it as "nothing major."
# Confidence Score: 70
#
# Simulation 70
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of cancer by stating their immediate family is generally healthy.
# Confidence Score: 0
#
# Simulation 71
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of cancer in their family history by stating it "doesn't seem to affect my immediate family."
# Confidence Score: 70
#
# Simulation 72
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of diabetes in their family, suggesting it is not widespread and well-managed, despite it being a notable family history.
# Confidence Score: 0
#
# Simulation 73
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to maintain an active lifestyle despite having a sedentary job.
# Confidence Score: 0
#
# Simulation 74
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to stay active "when I can," but their profile indicates they are very active.
# Confidence Score: 0
#
# Simulation 75
#
# Lie Detector Analysis:
# Detected Lie:  The customer is evasive about the specific types of cancer in their family history and minimizes its significance.
# Confidence Score: 0
#
# Simulation 76
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 77
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to have no ongoing health conditions, but their profile indicates poor current health.
# Confidence Score: 75
#
# Simulation 78
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their sedentary lifestyle, suggesting they incorporate light activities, which may not be sufficient for maintaining good health.
# Confidence Score: 70
#
# Simulation 79
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to incorporate light physical activity, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 80
#
# Lie Detector Analysis:
# Detected Lie: The customer may be downplaying the regularity and intensity of their exercise routine.
# Confidence Score: 60
#
# Simulation 81
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 82
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of hypertension, suggesting it is well-managed and not a major concern.
# Confidence Score: 0
#
# Simulation 83
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly claims to be "perfectly healthy," which may downplay their actual health status of being "fair."
# Confidence Score: 0
#
# Simulation 84
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims their current health is stable and only mentions minor concerns, despite their true profile indicating poor health.
# Confidence Score: 0
#
# Simulation 85
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of cancer.
# Confidence Score: 70
#
# Simulation 86
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays their sedentary lifestyle by frequently mentioning efforts to stay active.
# Confidence Score: 70
#
# Simulation 87
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be perfectly healthy, but their profile indicates poor current health.
# Confidence Score: 0
#
# Simulation 88
#
# Lie Detector Analysis:
# Detected Lie: The customer consistently refers to the knee surgery as a "minor procedure," which may downplay its significance.
# Confidence Score: 70
#
# Simulation 89
#
# Lie Detector Analysis:
# Detected Lie: The customer initially claimed the family history of cancer was limited to distant relatives, but later admitted it affects some close relatives.
# Confidence Score: 75
#
# Simulation 90
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 91
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of diabetes and their level of physical activity.
# Confidence Score: 70
#
# Simulation 92
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be "moderately active" and managing their health well, despite having a sedentary lifestyle and poor current health.
# Confidence Score: 90
#
# Simulation 93
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of cancer, suggesting it is less impactful than it might be.
# Confidence Score: 70
#
# Simulation 94
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed their health is "fair" and "manageable," but their profile indicates poor health.
# Confidence Score: 75
#
# Simulation 95
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of diabetes, suggesting it is not a major concern.
# Confidence Score: 70
#
# Simulation 96
#
# Lie Detector Analysis:
# Detected Lie: The customer describes their lifestyle as "moderately active" rather than "very active."
# Confidence Score: 70
#
# Simulation 97
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of cancer by only mentioning an aunt with breast cancer.
# Confidence Score: 0
#
# Simulation 98
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to maintain a "generally active lifestyle," but their profile indicates a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 99
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of heart disease in their family history, describing it as "manageable" and "not significant."
# Confidence Score: 75
#
# Simulation 100
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to maintain an active lifestyle and downplays their sedentary habits.
# Confidence Score: 0
#
# Simulation 101
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of heart disease in their family, suggesting it is not a major concern despite it being a notable part of their family history.
# Confidence Score: 0
#
# Simulation 102
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their activity level, stating it is not a significant focus, despite being "very active" in their true profile.
# Confidence Score: 0
#
# Simulation 103
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to have a moderately active lifestyle, but their profile indicates a sedentary habit.
# Confidence Score: 75
#
# Simulation 104
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of heart disease, suggesting it primarily affects older relatives, which may not fully capture the risk.
# Confidence Score: 0
#
# Simulation 105
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family history by describing it as "nothing major."
# Confidence Score: 75
#
# Simulation 106
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their knee surgery and its impact on their current health.
# Confidence Score: 0
#
# Simulation 107
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of family health issues, particularly hypertension.
# Confidence Score: 70
#
# Simulation 108
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of cancer in their family history, suggesting it is rare and not a major concern.
# Confidence Score: 75
#
# Simulation 109
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be "moderately active," but their profile indicates they are "very active."
# Confidence Score: 75
#
# Simulation 110
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of their family history of heart disease.
# Confidence Score: 70
#
# Simulation 111
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of their family history of cancer, suggesting it has little impact on their health.
# Confidence Score: 70
#
# Simulation 112
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their active lifestyle, stating it is not a major focus, despite being very active.
# Confidence Score: 0
#
# Simulation 113
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of hypertension in their family history, suggesting it hasn't had a significant impact.
# Confidence Score: 70
#
# Simulation 114
#
# Lie Detector Analysis:
# Detected Lie:  The customer is minimizing the significance of cancer in their family history, likely to avoid higher insurance premiums.
# Confidence Score: 0
#
# Simulation 115
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of diabetes in their family history and avoids providing specific details about ages at diagnosis.
# Confidence Score: 90
#
# Simulation 116
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of cancer by describing it as "nothing major."
# Confidence Score: 75
#
# Simulation 117
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of the family history of diabetes.
# Confidence Score: 70
#
# Simulation 118
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 119
#
# Lie Detector Analysis:
# Detected Lie: The customer initially avoids specifying the number of family members with diabetes, which could indicate an attempt to minimize the significance of this family health issue.
# Confidence Score: 70
#
# Simulation 120
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly states that the family history of cancer does not present a significant hereditary concern for them personally.
# Confidence Score: 0
#
# Simulation 121
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of family history of hypertension, suggesting it is well-managed and not a significant hereditary condition.
# Confidence Score: 0
#
# Simulation 122
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be "moderately active," but their occupation in manual labor suggests a higher activity level.
# Confidence Score: 70
#
# Simulation 123
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly emphasizes their health as "fairly stable" and "generally fair," potentially downplaying any ongoing issues.
# Confidence Score: 0
#
# Simulation 124
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of heart disease.
# Confidence Score: 70
#
# Simulation 125
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to be perfectly healthy with no significant medical history, despite their true profile indicating poor current health.
# Confidence Score: 90
#
# Simulation 126
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to maintain a healthy and active lifestyle, which contradicts their sedentary habits.
# Confidence Score: 75
#
# Simulation 127
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims their health is "fair" and only mentions minor skin issues, despite their true profile indicating poor health.
# Confidence Score: 0
#
# Simulation 128
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to stay active and maintain a balanced lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 129
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays their active lifestyle, which is described as "very active" in their true profile.
# Confidence Score: 70
#
# Simulation 130
#
# Lie Detector Analysis:
# Detected Lie:  The customer repeatedly mentions "one or two minor health issues" without specifying them, which could imply there are additional minor health issues not disclosed.
# Confidence Score: 0
#
# Simulation 131
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their past medical history by referring to the broken arm as "minor medical procedures."
# Confidence Score: 70
#
# Simulation 132
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of heart disease.
# Confidence Score: 70
#
# Simulation 133
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their sedentary lifestyle by emphasizing occasional activity.
# Confidence Score: 0
#
# Simulation 134
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 135
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays their very active lifestyle by describing it as casual and not a major focus.
# Confidence Score: 70
#
# Simulation 136
#
# Lie Detector Analysis:
# Detected Lie: The customer may be overstating their commitment to regular exercise.
# Confidence Score: 70
#
# Simulation 137
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of their family history of cancer, suggesting it is not a significant hereditary concern.
# Confidence Score: 75
#
# Simulation 138
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be moderately active due to their manual labor job, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 139
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims their overall health is "fair" and only mentions "occasional skin irritations," despite their profile indicating poor health.
# Confidence Score: 0
#
# Simulation 140
#
# Lie Detector Analysis:
# Detected Lie:  The customer minimizes the significance of the family history of heart disease, suggesting it is not a significant hereditary concern.
# Confidence Score: 0
#
# Simulation 141
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their sedentary lifestyle and past skin surgeries.
# Confidence Score: 70
#
# Simulation 142
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family history, suggesting it has not significantly impacted their health or that of their immediate family.
# Confidence Score: 70
#
# Simulation 143
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their sedentary lifestyle by emphasizing efforts to stay active.
# Confidence Score: 0
#
# Simulation 144
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family history, describing it as "nothing major."
# Confidence Score: 75
#
# Simulation 145
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of the family history of diabetes, suggesting it has not impacted their health.
# Confidence Score: 70
#
# Simulation 146
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family history by describing it as "nothing major."
# Confidence Score: 75
#
# Simulation 147
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 148
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their minor skin surgeries, suggesting they are routine and not impactful to their health.
# Confidence Score: 70
#
# Simulation 149
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family history, avoiding specifics about serious heart-related events.
# Confidence Score: 90
#
# Simulation 150
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their sedentary lifestyle by repeatedly emphasizing efforts to stay active.
# Confidence Score: 0
#
# Simulation 151
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of cancer, suggesting it is limited to older generations and not a major concern.
# Confidence Score: 0
#
# Simulation 152
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to maintain a moderately active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 153
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of diabetes in their family history, referring to it as "nothing major."
# Confidence Score: 0
#
# Simulation 154
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to focus on staying active and healthy within their lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 155
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their sedentary lifestyle by describing it as balanced and mentioning occasional light workouts.
# Confidence Score: 70
#
# Simulation 156
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to be moderately active and focused on staying active, despite having a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 157
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to stay active and engage in light activities, despite having a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 158
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of hypertension, describing it as "nothing major."
# Confidence Score: 0
#
# Simulation 159
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to be "perfectly healthy" with no significant medical history, despite having poor current health and a sedentary lifestyle.
# Confidence Score: 90
#
# Simulation 160
#
# Lie Detector Analysis:
# Detected Lie: The customer is evasive about the specific types of cancer in their family history, likely to downplay the risk.
# Confidence Score: 75
#
# Simulation 161
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their physical activity level, describing it as "moderately active" instead of "very active."
# Confidence Score: 0
#
# Simulation 162
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to engage in a moderately active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 163
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their knee surgery by referring to it as a "minor health issue."
# Confidence Score: 70
#
# Simulation 164
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to maintain a healthy lifestyle and stay active, but their profile indicates a sedentary lifestyle.
# Confidence Score: 70
#
# Simulation 165
#
# Lie Detector Analysis:
# Detected Lie:  The customer is evasive about the specific types of cancer in their family, suggesting they may be downplaying the prevalence or significance of these conditions.
# Confidence Score: 0
#
# Simulation 166
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to stay active and incorporate physical activity into their routine, but their profile indicates a sedentary lifestyle.
# Confidence Score: 70
#
# Simulation 167
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of cancer in their family history, suggesting it is not a significant hereditary condition.
# Confidence Score: 75
#
# Simulation 168
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to maintain a healthy lifestyle and have stable health, but their profile indicates a sedentary lifestyle and poor current health.
# Confidence Score: 90
#
# Simulation 169
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of diabetes, suggesting it is not a major concern despite it being present.
# Confidence Score: 70
#
# Simulation 170
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 171
#
# Lie Detector Analysis:
# Detected Lie: The customer minimizes the significance of diabetes in their family history.
# Confidence Score: 90
#
# Simulation 172
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 173
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of heart disease in their family, suggesting it has not had a major impact on their health or lifestyle.
# Confidence Score: 75
#
# Simulation 174
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 175
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 176
#
# Lie Detector Analysis:
# Detected Lie:  The customer minimizes the significance of their minor skin surgeries and the impact of their family history of heart disease.
# Confidence Score: 0
#
# Simulation 177
#
# Lie Detector Analysis:
# Detected Lie: The customer is evasive about the specifics of their family history of cancer, which may indicate an attempt to downplay its significance.
# Confidence Score: 70
#
# Simulation 178
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays the significance of their family history of cancer.
# Confidence Score: 70
#
# Simulation 179
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 180
#
# Lie Detector Analysis:
# Detected Lie:  The customer may be downplaying the significance of their past medical procedures and family health issues.
# Confidence Score: 0
#
# Simulation 181
#
# Lie Detector Analysis:
# Detected Lie:  The customer may be minimizing the significance of their past medical procedures.
# Confidence Score: 0
#
# Simulation 182
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 183
#
# Lie Detector Analysis:
# Detected Lie: The customer downplays their physical activity, suggesting it is not a major focus, despite being very active.
# Confidence Score: 70
#
# Simulation 184
#
# Lie Detector Analysis:
# Detected Lie:  None
# Confidence Score: 0
#
# Simulation 185
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 186
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed to be "very active" but later downplayed the significance of their physical activity.
# Confidence Score: 70
#
# Simulation 187
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to maintain a moderately active lifestyle, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 188
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 189
#
# Lie Detector Analysis:
# Detected Lie:  The customer claims to manage fatigue and stress effectively through lifestyle changes, despite their poor current health status.
# Confidence Score: 0
#
# Simulation 190
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays their current health status, describing it as "a bit on the lower side" and "occasional fatigue and discomfort," despite their true profile indicating poor health.
# Confidence Score: 0
#
# Simulation 191
#
# Lie Detector Analysis:
# Detected Lie: None
# Confidence Score: 0
#
# Simulation 192
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 193
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the severity of their parents' heart disease, describing it as "minor heart-related issues" and "well-managed," which may not fully capture the seriousness of the conditions.
# Confidence Score: 0
#
# Simulation 194
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to stay active and maintain a healthy routine, despite having a sedentary lifestyle.
# Confidence Score: 75
#
# Simulation 195
#
# Lie Detector Analysis:
# Detected Lie: The customer claimed their current health is stable, but their profile indicates poor health.
# Confidence Score: 90
#
# Simulation 196
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active" due to their manual labor job, but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 197
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed to be "moderately active," but their profile indicates a sedentary lifestyle.
# Confidence Score: 0
#
# Simulation 198
#
# Lie Detector Analysis:
# Detected Lie:  The customer downplays the significance of their family history of cancer by stating their parents are doing well now, which may not fully capture the potential genetic risk.
# Confidence Score: 0
#
# Simulation 199
#
# Lie Detector Analysis:
# Detected Lie: The customer claims to maintain an active lifestyle with light exercise, but their profile indicates a sedentary lifestyle.
# Confidence Score: 70
#
# Simulation 200
#
# Lie Detector Analysis:
# Detected Lie:  The customer claimed that heart disease is only present in distant relatives, minimizing its significance in their family history.
# Confidence Score: 0
